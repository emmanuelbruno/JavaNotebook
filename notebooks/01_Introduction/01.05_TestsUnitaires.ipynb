// %% [markdown]
// # Les tests unitaires en Java
// From https://github.com/junit-team/junit4/wiki/Getting-started

// %%
%%shell
export JAVA_PROJECTS="/notebooks/01_Introduction/resources/01.05/MyJunitApp"
cd "$JAVA_PROJECTS"
\cp Calculator.java src/main/java/fr/univtln/bruno/Calculator.java
\cp CalculatorTest.java src/test/java/fr/univtln/bruno/CalculatorTest.java    
mvn -ntp test
// Out:
// [INFO] Scanning for projects...
// [INFO]
// [INFO] ---------------------< fr.univtln.bruno:JunitApp >----------------------
// [INFO] Building JunitApp 1.0-SNAPSHOT
// [INFO] --------------------------------[ jar ]---------------------------------
// [INFO]
// [INFO] --- maven-resources-plugin:3.0.2:resources (default-resources) @ JunitApp ---
// [INFO] Using 'UTF-8' encoding to copy filtered resources.
// [INFO] skip non existing resourceDirectory /notebooks/01_Introduction/resources/01.05/MyJunitApp/src/main/resources
// [INFO]
// [INFO] --- maven-compiler-plugin:3.8.0:compile (default-compile) @ JunitApp ---
// [INFO] Changes detected - recompiling the module!
// [INFO] Compiling 1 source file to /notebooks/01_Introduction/resources/01.05/MyJunitApp/target/classes
// [INFO]
// [INFO] --- maven-resources-plugin:3.0.2:testResources (default-testResources) @ JunitApp ---
// [INFO] Using 'UTF-8' encoding to copy filtered resources.
// [INFO] skip non existing resourceDirectory /notebooks/01_Introduction/resources/01.05/MyJunitApp/src/test/resources
// [INFO]
// [INFO] --- maven-compiler-plugin:3.8.0:testCompile (default-testCompile) @ JunitApp ---
// [INFO] Changes detected - recompiling the module!
// [INFO] Compiling 1 source file to /notebooks/01_Introduction/resources/01.05/MyJunitApp/target/test-classes
// [INFO]
// [INFO] --- maven-surefire-plugin:2.22.1:test (default-test) @ JunitApp ---
// [INFO]
// [INFO] -------------------------------------------------------
// [INFO]  T E S T S
// [INFO] -------------------------------------------------------
// [INFO] Running fr.univtln.bruno.CalculatorTest
// [INFO] Tests run: 1, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.064 s - in fr.univtln.bruno.CalculatorTest
// [INFO]
// [INFO] Results:
// [INFO]
// [INFO] Tests run: 1, Failures: 0, Errors: 0, Skipped: 0
// [INFO]
// [INFO] ------------------------------------------------------------------------
// [INFO] BUILD SUCCESS
// [INFO] ------------------------------------------------------------------------
// [INFO] Total time:  2.333 s
// [INFO] Finished at: 2020-11-23T22:22:16Z
// [INFO] ------------------------------------------------------------------------

// %%
%%shell
export JAVA_PROJECTS="/notebooks/01_Introduction/resources/01.05/MyJunitApp"
tree "$JAVA_PROJECTS"
// Out:
// /notebooks/01_Introduction/resources/01.05/MyJunitApp
// ├── Calculator-with-error.java
// ├── Calculator.java
// ├── CalculatorTest-advanced.java
// ├── CalculatorTest.java
// ├── pom.xml
// ├── src
// │   ├── main
// │   │   └── java
// │   │       └── fr
// │   │           └── univtln
// │   │               └── bruno
// │   │                   └── Calculator.java
// │   └── test
// │       └── java
// │           └── fr
// │               └── univtln
// │                   └── bruno
// │                       └── CalculatorTest.java
// └── target
//     ├── JunitApp-1.0-SNAPSHOT.jar
//     ├── classes
//     │   └── fr
//     │       └── univtln
//     │           └── bruno
//     │               └── Calculator.class
//     ├── generated-sources
//     │   └── annotations
//     ├── generated-test-sources
//     │   └── test-annotations
//     ├── maven-archiver
//     │   └── pom.properties
//     ├── maven-status
//     │   └── maven-compiler-plugin
//     │       ├── compile
//     │       │   └── default-compile
//     │       │       ├── createdFiles.lst
//     │       │       └── inputFiles.lst
//     │       └── testCompile
//     │           └── default-testCompile
//     │               ├── createdFiles.lst
//     │               └── inputFiles.lst
//     ├── surefire-reports
//     │   ├── TEST-fr.univtln.bruno.CalculatorTest.xml
//     │   └── fr.univtln.bruno.CalculatorTest.txt
//     └── test-classes
//         └── fr
//             └── univtln
//                 └── bruno
//                     └── CalculatorTest.class
//
// 32 directories, 17 files

// %%
%%shell
export JAVA_PROJECTS="/notebooks/01_Introduction/resources/01.05/MyJunitApp"
cd "$JAVA_PROJECTS"
\cp Calculator-with-error.java src/main/java/fr/univtln/bruno/Calculator.java    
mvn -ntp test
// Out:
// [INFO] Scanning for projects...
// [INFO]
// [INFO] ---------------------< fr.univtln.bruno:JunitApp >----------------------
// [INFO] Building JunitApp 1.0-SNAPSHOT
// [INFO] --------------------------------[ jar ]---------------------------------
// [INFO]
// [INFO] --- maven-resources-plugin:3.0.2:resources (default-resources) @ JunitApp ---
// [INFO] Using 'UTF-8' encoding to copy filtered resources.
// [INFO] skip non existing resourceDirectory /notebooks/01_Introduction/resources/01.05/MyJunitApp/src/main/resources
// [INFO]
// [INFO] --- maven-compiler-plugin:3.8.0:compile (default-compile) @ JunitApp ---
// [INFO] Changes detected - recompiling the module!
// [INFO] Compiling 1 source file to /notebooks/01_Introduction/resources/01.05/MyJunitApp/target/classes
// [INFO]
// [INFO] --- maven-resources-plugin:3.0.2:testResources (default-testResources) @ JunitApp ---
// [INFO] Using 'UTF-8' encoding to copy filtered resources.
// [INFO] skip non existing resourceDirectory /notebooks/01_Introduction/resources/01.05/MyJunitApp/src/test/resources
// [INFO]
// [INFO] --- maven-compiler-plugin:3.8.0:testCompile (default-testCompile) @ JunitApp ---
// [INFO] Nothing to compile - all classes are up to date
// [INFO]
// [INFO] --- maven-surefire-plugin:2.22.1:test (default-test) @ JunitApp ---
// [INFO]
// [INFO] -------------------------------------------------------
// [INFO]  T E S T S
// [INFO] -------------------------------------------------------
// [INFO] Running fr.univtln.bruno.CalculatorTest
// [ERROR] Tests run: 1, Failures: 1, Errors: 0, Skipped: 0, Time elapsed: 0.05 s <<< FAILURE! - in fr.univtln.bruno.CalculatorTest
// [ERROR] evaluatesExpression(fr.univtln.bruno.CalculatorTest)  Time elapsed: 0.007 s  <<< FAILURE!
// java.lang.AssertionError: expected:<6> but was:<-6>
// 	at fr.univtln.bruno.CalculatorTest.evaluatesExpression(CalculatorTest.java:12)
//
// [INFO]
// [INFO] Results:
// [INFO]
// [ERROR] Failures:
// [ERROR]   CalculatorTest.evaluatesExpression:12 expected:<6> but was:<-6>
// [INFO]
// [ERROR] Tests run: 1, Failures: 1, Errors: 0, Skipped: 0
// [INFO]
// [INFO] ------------------------------------------------------------------------
// [INFO] BUILD FAILURE
// [INFO] ------------------------------------------------------------------------
// [INFO] Total time:  1.953 s
// [INFO] Finished at: 2020-11-23T17:27:25Z
// [INFO] ------------------------------------------------------------------------
// [ERROR] Failed to execute goal org.apache.maven.plugins:maven-surefire-plugin:2.22.1:test (default-test) on project JunitApp: There are test failures.
// [ERROR]
// [ERROR] Please refer to /notebooks/01_Introduction/resources/01.05/MyJunitApp/target/surefire-reports for the individual test results.
// [ERROR] Please refer to dump files (if any exist) [date].dump, [date]-jvmRun[N].dump and [date].dumpstream.
// [ERROR] -> [Help 1]
// [ERROR]
// [ERROR] To see the full stack trace of the errors, re-run Maven with the -e switch.
// [ERROR] Re-run Maven using the -X switch to enable full debug logging.
// [ERROR]
// [ERROR] For more information about the errors and possible solutions, please read the following articles:
// [ERROR] [Help 1] http://cwiki.apache.org/confluence/display/MAVEN/MojoFailureException

// %%
%%shell
export JAVA_PROJECTS="/notebooks/01_Introduction/resources/01.05/MyJunitApp"
cd "$JAVA_PROJECTS"
\cp Calculator.java src/main/java/fr/univtln/bruno/Calculator.java    
\cp CalculatorTest-advanced.java src/test/java/fr/univtln/bruno/CalculatorTest.java    
mvn -ntp test
// Out:
// [INFO] Scanning for projects...
// [INFO]
// [INFO] ---------------------< fr.univtln.bruno:JunitApp >----------------------
// [INFO] Building JunitApp 1.0-SNAPSHOT
// [INFO] --------------------------------[ jar ]---------------------------------
// [INFO]
// [INFO] --- maven-resources-plugin:3.0.2:resources (default-resources) @ JunitApp ---
// [INFO] Using 'UTF-8' encoding to copy filtered resources.
// [INFO] skip non existing resourceDirectory /notebooks/01_Introduction/resources/01.05/MyJunitApp/src/main/resources
// [INFO]
// [INFO] --- maven-compiler-plugin:3.8.0:compile (default-compile) @ JunitApp ---
// [INFO] Changes detected - recompiling the module!
// [INFO] Compiling 1 source file to /notebooks/01_Introduction/resources/01.05/MyJunitApp/target/classes
// [INFO]
// [INFO] --- maven-resources-plugin:3.0.2:testResources (default-testResources) @ JunitApp ---
// [INFO] Using 'UTF-8' encoding to copy filtered resources.
// [INFO] skip non existing resourceDirectory /notebooks/01_Introduction/resources/01.05/MyJunitApp/src/test/resources
// [INFO]
// [INFO] --- maven-compiler-plugin:3.8.0:testCompile (default-testCompile) @ JunitApp ---
// [INFO] Changes detected - recompiling the module!
// [INFO] Compiling 1 source file to /notebooks/01_Introduction/resources/01.05/MyJunitApp/target/test-classes
// [INFO]
// [INFO] --- maven-surefire-plugin:2.22.1:test (default-test) @ JunitApp ---
// [INFO]
// [INFO] -------------------------------------------------------
// [INFO]  T E S T S
// [INFO] -------------------------------------------------------
// [INFO] Running fr.univtln.bruno.CalculatorTest
// Using @BeforeClass, executed before all test cases.
// Using @Before, executed before each test case.
// Using @Test(expected) ,it will check for specified exception during its execution
// Using @After, executed after each test case.
// Using @Before, executed before each test case.
// Test 2
// Using @After, executed after each test case.
// Using @Before, executed before each test case.
// Test 3
// Using @After, executed after each test case.
// Using @Before, executed before each test case.
// Using @After, executed after each test case.
// Using @AfterClass, executed after all test cases.
// [WARNING] Tests run: 5, Failures: 0, Errors: 0, Skipped: 1, Time elapsed: 0.066 s - in fr.univtln.bruno.CalculatorTest
// [INFO]
// [INFO] Results:
// [INFO]
// [WARNING] Tests run: 5, Failures: 0, Errors: 0, Skipped: 1
// [INFO]
// [INFO] ------------------------------------------------------------------------
// [INFO] BUILD SUCCESS
// [INFO] ------------------------------------------------------------------------
// [INFO] Total time:  2.076 s
// [INFO] Finished at: 2020-11-23T17:27:48Z
// [INFO] ------------------------------------------------------------------------

// %%
%maven junit:junit:4.13.1
import static org.junit.Assert.*;
assertTrue("Erreur 1", 1 == 1);
assertTrue("Erreur 2",1 == 2);
// Out:
// ---------------------------------------------------------------------------
// java.lang.AssertionError: Erreur 2
// 	at org.junit.Assert.fail(Assert.java:89)
// 	at org.junit.Assert.assertTrue(Assert.java:42)
// 	at .(#36:1)
