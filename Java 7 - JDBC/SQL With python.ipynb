# %%
import sys
# !{sys.executable} -m pip install SQLAlchemy psycopg2-binary pandas

import pandas as pd

from sqlalchemy import Table, MetaData, create_engine
engine = create_engine("postgresql+psycopg2://postgres:changeme@db:5432/dvdrental")

# %%
films = pd.read_sql_table("film",
                           con=engine)
films
# Out:
#      film_id              title  \
# 0        133    Chamber Italian
# 1        384   Grosse Wonderful
# 2          8    Airport Pollock
# 3         98  Bright Encounters
# 4          1   Academy Dinosaur
# ..       ...                ...
# 995      996     Young Language
# 996      997         Youth Kick
# 997      998       Zhivago Core
# 998      999  Zoolander Fiction
# 999     1000          Zorro Ark
#
#                                            description  release_year  \
# 0    A Fateful Reflection of a Moose And a Husband ...          2006
# 1    A Epic Drama of a Cat And a Explorer who must ...          2006
# 2    A Epic Tale of a Moose And a Girl who must Con...          2006
# 3    A Fateful Yarn of a Lumberjack And a Feminist ...          2006
# 4    A Epic Drama of a Feminist And a Mad Scientist...          2006
# ..                                                 ...           ...
# 995  A Unbelieveable Yarn of a Boat And a Database ...          2006
# ...

# %%
pd.read_sql("SELECT * FROM film WHERE length<60", con=engine)
# Out:
#     film_id                title  \
# 0       384     Grosse Wonderful
# 1         8      Airport Pollock
# 2         2       Ace Goldfinger
# 3         3     Adaptation Holes
# 4        15         Alien Center
# ..      ...                  ...
# 91      947        Vision Torque
# 92      970  Westward Seabiscuit
# 93      972      Whisperer Giant
# 94      981        Wolves Desire
# 95     1000            Zorro Ark
#
#                                           description  release_year  \
# 0   A Epic Drama of a Cat And a Explorer who must ...          2006
# 1   A Epic Tale of a Moose And a Girl who must Con...          2006
# 2   A Astounding Epistle of a Database Administrat...          2006
# 3   A Astounding Reflection of a Lumberjack And a ...          2006
# 4   A Brilliant Drama of a Cat And a Mad Scientist...          2006
# ..                                                ...           ...
# 91  A Thoughtful Documentary of a Dog And a Man wh...          2006
# ...

# %%
pd.read_sql_table("city",con=engine)
# Out:
#      city_id                city  country_id         last_update
# 0          1  A Corua (La Corua)          87 2006-02-15 09:45:25
# 1          2                Abha          82 2006-02-15 09:45:25
# 2          3           Abu Dhabi         101 2006-02-15 09:45:25
# 3          4                Acua          60 2006-02-15 09:45:25
# 4          5               Adana          97 2006-02-15 09:45:25
# ..       ...                 ...         ...                 ...
# 595      596               Zaria          69 2006-02-15 09:45:25
# 596      597        Zeleznogorsk          80 2006-02-15 09:45:25
# 597      598         Zhezqazghan          51 2006-02-15 09:45:25
# 598      599            Zhoushan          23 2006-02-15 09:45:25
# 599      600          Ziguinchor          83 2006-02-15 09:45:25
#
# [600 rows x 4 columns]

# %%
pd.read_sql("SELECT * from country where country='France'",con=engine)
# Out:
#    country_id country         last_update
# 0          34  France 2006-02-15 09:44:00

# %%
pd.read_sql("SELECT * from city where city='Garéoult'",con=engine)
# Out:
#    city_id      city  country_id                last_update
# 0      601  Garéoult          34 2020-03-25 08:54:06.626356
# 1      602  Garéoult          34 2020-03-25 08:55:15.079133
